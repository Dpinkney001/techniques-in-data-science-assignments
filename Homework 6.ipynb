# %% [markdown]
# Duvall Pinkney NEW YORK MAP Homework 2/22/2021

# %% [markdown]
# # Homework 6
#
# There are no written questions for this homework.
#
# ### Question 1
# Create a map of New York showing the locations of all the CUNY colleges.  Each marker should be labeled with the name of the college.
#
# The coordinates for the CUNY colleges are on NYC Open Data: [https://data.ny.gov/Education/City-University-of-New-York-CUNY-University-Campus/irqs-74ez/data](https://data.ny.gov/Education/City-University-of-New-York-CUNY-University-Campus/irqs-74ez/data)
#
# URL for CSV file:  [https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/CUNY_Campus_Locations.csv](https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/CUNY_Campus_Locations.csv)

# %%
import folium
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/CUNY_Campus_Locations.csv",na_values = "-")
data
# Out:
#    College or Institution Type                                     Campus  \
# 0              Senior Colleges                             Baruch College
# 1           Community Colleges     Borough of Manhattan Community College
# 2           Community Colleges                    Bronx Community College
# 3              Senior Colleges                           Brooklyn College
# 4       Comprehensive Colleges                   College of Staten Island
# 5           Community Colleges                  Guttman Community College
# 6           Community Colleges                   Hostos Community College
# 7              Senior Colleges                             Hunter College
# 8              Senior Colleges       John Jay College of Criminal Justice
# 9           Community Colleges             Kingsborough Community College
# 10          Community Colleges                LaGuardia Community College
# 11             Senior Colleges                             Lehman College
# ...

# %%
data.describe()
# Out:
#         Latitude  Longitude
# count  22.000000  22.000000
# mean   40.737468 -73.948658
# std     0.072631   0.075514
# min    40.578349 -74.153563
# 25%    40.706457 -73.985915
# 50%    40.746313 -73.956447
# 75%    40.765384 -73.928763
# max    40.873442 -73.795776

# %%
m = folium.Map(location=[40.8747, -73.8951])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for i in range(25):
    row = data.iloc[i]
    folium.Marker([row["Latitude"],row["Longitude"]], 
              popup='New York', 
              tooltip="Click for info",
              icon=folium.Icon(color='red', icon='info-sign')
             ).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b889f4c24f00> in <module>
#       4               popup='New York',
#       5               tooltip="Click for info",
# ----> 6               icon=folium.Icon(color='red', icon='info-sign')
#       7              ).add_to(m)
#       8 m
#
# ~\AppData\Roaming\Python\Python37\site-packages\folium\map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     275         super(Marker, self).__init__()
#     276         self._name = 'Marker'
# --> 277         self.location = validate_location(location) if location else None
#     278         self.options = parse_options(
#     279             draggable=draggable or None,
#
# ~\AppData\Roaming\Python\Python37\site-packages\folium\utilities.py in validate_location(location)
#      64                              .format(coord, type(coord)))
# ...

# %% [markdown]
# ### Question 2
# As in Question 1, create a map of New York showing the locations of all CUNY College, labeled by the name of the college.
#
# For this map, the senior colleges should be one color and all other colleges should be a different color (your choice of colors).
#
# <details><summary>Hint:</summary>
# There are multiple ways to do this question.  One way is to use filters to make smaller datasets and plot each one separately.  Another way is using conditional (if) statements.
# </details>

# %%
senior = data["College or Institution Type"] == 'Senior Colleges'
data[senior]
# Out:
#    College or Institution Type                                Campus  \
# 0              Senior Colleges                        Baruch College
# 3              Senior Colleges                      Brooklyn College
# 7              Senior Colleges                        Hunter College
# 8              Senior Colleges  John Jay College of Criminal Justice
# 11             Senior Colleges                        Lehman College
# 16             Senior Colleges                        Queens College
# 20             Senior Colleges                    School of Medicine
# 23             Senior Colleges          The City College of New York
# 25             Senior Colleges                          York College
#
#                    Campus Website                          Address      City  \
# 0          http://baruch.cuny.edu  55 Lexington Ave at 24th Street  New York
# 3             http://brooklyn.edu              2900 Bedford Avenue  Brooklyn
# ...

# %%
filternan = data["Campus"] != "School of Medicine"
newdata = data[filternan]
senior = newdata["College or Institution Type"] == 'Senior Colleges'
newdata[senior]
# Out:
#    College or Institution Type                                Campus  \
# 0              Senior Colleges                        Baruch College
# 3              Senior Colleges                      Brooklyn College
# 7              Senior Colleges                        Hunter College
# 8              Senior Colleges  John Jay College of Criminal Justice
# 11             Senior Colleges                        Lehman College
# 16             Senior Colleges                        Queens College
# 23             Senior Colleges          The City College of New York
# 25             Senior Colleges                          York College
#
#             Campus Website                          Address      City State  \
# 0   http://baruch.cuny.edu  55 Lexington Ave at 24th Street  New York    NY
# 3      http://brooklyn.edu              2900 Bedford Avenue  Brooklyn    NY
# 7   http://hunter.cuny.edu                  695 Park Avenue  New York    NY
# ...

# %%
newdata[senior].describe()
# Out:
#         Latitude  Longitude
# count   8.000000   8.000000
# mean   40.755256 -73.918234
# std     0.073125   0.074677
# min    40.630276 -73.986469
# 25%    40.727942 -73.969749
# 50%    40.754854 -73.952532
# 75%    40.782341 -73.872029
# max    40.873442 -73.795776

# %%
n = folium.Map(location=[40.8747, -73.8951])
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for i in range(8):
    row = newdata[senior].iloc[i]
    folium.Marker([row["Latitude"],row["Longitude"]], 
              popup='New York', 
              tooltip="Click for info",
              icon=folium.Icon(color='blue', icon='info-sign')
             ).add_to(n)
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
