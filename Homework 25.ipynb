# %% [markdown]
# # Homework 25 Solutions
#
# This assignment uses the dataset of all NYC restaurant inspection results from Jan. 1, 2019 - Aug. 30, 2019 from Homework 24. The original, unfiltered dataset is at https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/43nn-pn8j.
#
# Download the filtered dataset from: [https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/DOHMH_New_York_City_Restaurant_Inspection_Results_Feb2020.csv](https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/DOHMH_New_York_City_Restaurant_Inspection_Results_Feb2020.csv)
#
# Information about how restaurants are inspected and graded in NYC is here: https://www1.nyc.gov/assets/doh/downloads/pdf/rii/how-we-score-grade.pdf(https://www1.nyc.gov/assets/doh/downloads/pdf/rii/how-we-score-grade.pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Question 1:  Load and clean the data
#
# Load the restaurant data and do the following to clean it:
# 1. Create a new DataFrame with only the columns `BORO` (the restaurant's borough) and `SCORE` (the restaurant's inspection score).
# 2. Remove any rows in the new DataFrame with missing data.
# 3. Filter the data to only keep the restaurants (rows) in the Bronx and Queens.

# %%
url = "https://raw.githubusercontent.com/megan-owen/MAT328-Techniques_in_Data_Science/main/data/DOHMH_New_York_City_Restaurant_Inspection_Results_Feb2020.csv"
df = pd.read_csv(url)
df
# Out:
#           CAMIS                       DBA      BORO BUILDING  \
# 0      41722899  MI CANDILEJAS RESTAURANT  Brooklyn     1509
# 1      50015528       THE BEAST NEXT DOOR    Queens    42-51
# 2      50073026           HIBACHI STATION    Queens     8312
# 3      50081649    PAULIE GEE SLICE JOINT  Brooklyn      110
# 4      41127209           BACI & ABBRACCI  Brooklyn      204
# ...         ...                       ...       ...      ...
# 12592  50095050       GREEK GRILL TAVERNA    Queens     6517
# 12593  50033484       TULCINGO RESTAURANT    Queens     9558
# 12594  41499986            EL GAUCHITO II    Queens    15815
# 12595  50055957           LAO JIE HOT POT  Brooklyn      811
# 12596  50055957           LAO JIE HOT POT  Brooklyn      811
#
#                           STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0                 MERMAID AVENUE  11224.0  7182666161      Latin American
# 1                      27 STREET  11101.0  6466392345            American
# 2                       37TH AVE  11372.0  6466332522            Japanese
# 3                FRANKLIN STREET  11222.0  9293376385               Pizza
# 4                   GRAND STREET  11211.0  7185996599             Italian
# ...                          ...      ...         ...                 ...
# 12592              FRESH POND RD  11385.0  7183662001               Greek
# 12593              ROOSEVELT AVE  11372.0  7184240404             Mexican
# 12594  HORACE HARDING EXPRESSWAY  11365.0  7186614262      Latin American
# 12595                  53 STREET  11220.0  7184310026             Chinese
# 12596                  53 STREET  11220.0  7184310026             Chinese
#
#       INSPECTION DATE ACTION  ... RECORD DATE  \
# 0          02/01/2020      U  ...  04/30/2021
# 1          02/01/2020      D  ...  04/30/2021
# 2          02/01/2020      D  ...  04/30/2021
# 3          02/01/2020      D  ...  04/30/2021
# 4          02/01/2020      D  ...  04/30/2021
# ...               ...    ...  ...         ...
# 12592      02/29/2020      U  ...  04/30/2021
# 12593      02/29/2020      F  ...  04/30/2021
# 12594      02/29/2020      U  ...  04/30/2021
# 12595      02/29/2020      U  ...  04/30/2021
# 12596      02/29/2020      U  ...  04/30/2021
#
#                                 INSPECTION TYPE   Latitude  Longitude  \
# 0         Cycle Inspection / Initial Inspection  40.576835 -73.982872
# 1              Cycle Inspection / Re-inspection  40.748916 -73.940980
# 2         Cycle Inspection / Initial Inspection  40.749852 -73.883160
# 3         Cycle Inspection / Initial Inspection  40.728349 -73.957332
# 4         Cycle Inspection / Initial Inspection  40.714096 -73.960342
# ...                                         ...        ...        ...
# 12592  Pre-permit (Operational) / Re-inspection  40.709510 -73.898774
# 12593          Cycle Inspection / Re-inspection  40.749083 -73.870010
# 12594     Cycle Inspection / Initial Inspection  40.738844 -73.810110
# 12595          Cycle Inspection / Re-inspection  40.639179 -74.005026
# 12596          Cycle Inspection / Re-inspection  40.639179 -74.005026
#
#       Community Board Council District Census Tract        BIN           BBL  \
# 0               313.0             47.0      34800.0  3256857.0  3.070220e+09
# 1               402.0             26.0       1900.0  4005106.0  4.004310e+09
# 2               403.0             21.0      28100.0  4036224.0  4.014710e+09
# 3               301.0             33.0      56100.0  3064950.0  3.025690e+09
# 4               301.0             34.0      55100.0  3062796.0  3.023930e+09
# ...               ...              ...          ...        ...           ...
# 12592           405.0             30.0      61301.0  4087550.0  4.036110e+09
# 12593           404.0             21.0      46500.0  4039787.0  4.015940e+09
# 12594           407.0             20.0     121500.0  4146369.0  4.067360e+09
# 12595           312.0             38.0      10600.0  3138502.0  3.056580e+09
# 12596           312.0             38.0      10600.0  3138502.0  3.056580e+09
#
#         NTA
# 0      BK21
# 1      QN31
# 2      QN28
# 3      BK76
# 4      BK73
# ...     ...
# 12592  QN20
# 12593  QN29
# 12594  QN62
# 12595  BK34
# 12596  BK34
#
# [12597 rows x 26 columns]

# %%
df2 = df[["BORO","SCORE"]]
df2
# Out:
#            BORO  SCORE
# 0      Brooklyn   27.0
# 1        Queens   10.0
# 2        Queens    9.0
# 3      Brooklyn   12.0
# 4      Brooklyn   12.0
# ...         ...    ...
# 12592    Queens   27.0
# 12593    Queens   57.0
# 12594    Queens   19.0
# 12595  Brooklyn   -1.0
# 12596  Brooklyn   -1.0
#
# [12597 rows x 2 columns]

# %%
df2.dropna()
df2
# Out:
#            BORO  SCORE
# 0      Brooklyn   27.0
# 1        Queens   10.0
# 2        Queens    9.0
# 3      Brooklyn   12.0
# 4      Brooklyn   12.0
# ...         ...    ...
# 12592    Queens   27.0
# 12593    Queens   57.0
# 12594    Queens   19.0
# 12595  Brooklyn   -1.0
# 12596  Brooklyn   -1.0
#
# [12597 rows x 2 columns]

# %% [markdown]
# ### Question 2
#
# Is the mean inspection score different for restaurants in the Bronx that for restaurants in Queens?  We will conduct a permutation test to answer this question.
#
# the department of health ranks resturants cleanliness by a score
#
# #### Question 2a
# What are the null and alternative hypotheses?
#
# the mean inspection score is different for restautants in the bronx than for resturants in Queens

# %% [markdown]
# ### Question 2b
# Compute the test statistic from the data.  That is, compute the difference between the mean test score for Bronx restaurants and the mean test score for Queens restaurants.

# %%
bronxfilter = df2["BORO"] == "Bronx" 
queensfilter = df2["BORO"] == "Queens"

df3 = df2[bronxfilter]
df4 = df2[queensfilter]

df3
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-2c80cc8cf3d2> in <module>
# ----> 1 bronxfilter = df2["BORO"] == "Bronx"
#       2 queensfilter = df2["BORO"] == "Queens"
#       3
#       4 df3 = df2[bronxfilter]
#       5 df4 = df2[queensfilter]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'BORO'

# %% [markdown]
# ### Question 2c
#
# Add a new column to your DataFrame that is a permutation of the restaurant boroughs column.

# %%
new_columns = ["BORO","SCORE","permutation"]
df2.columns = new_columns
df2
# Out:
# 47       True
# 58       True
# 61       True
# 65       True
# 101      True
#          ...
# 12455    True
# 12486    True
# 12517    True
# 12545    True
# 12581    True
# Name: BORO, Length: 1192, dtype: bool

# %% [markdown]
# ### Question 2d
#
# Use a permutation test to find the distribution of the test statistic (the difference between the means) under the null hypothesis.  That is, using the Bronx and Queens restaurant data, do 10,00, simulations where the borough column is permuted and the difference of the mean score of the Bronx restaurants and the mean score of the Queens restaurants for the permuted data is computed.
#
# Plot a histogram of these these mean differences.

# %%
 df.hist()
# Out:
# C:\Users\thees\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\thees\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\thees\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\thees\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028062E1D448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028062E41248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028062E73708>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028062EA5BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028062EE2508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028062F10FC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028062F47D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028062F7F7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028062F7F8C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028062FB7588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028063028C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028063060B88>]],
#       dtype=object)

# %% [markdown]
# ### Question 2e
#
# Use the data test statistic computed in (2b) and the histogram from (2d) to reject or fail to reject the null hypothesis.  What is your conclusion and why?
